# %% [markdown]
# # Escitala
# Cambiar ruta original *rutaOriginal* por el texto deseado.
#
# Cambiar *longitudLinia* por la largada que quieras imprimir de cada iteración.

# %%
rutaOriginal = 'Escitala'
fichero = open(rutaOriginal)
texto = fichero.read()
fichero.close
print(texto[0:20])
# Out:
# I,renyl eCitinn oasn

# %%
longitudLinia = 50
for filas in range(1, 200):
    print("Vuelta en " + str(filas) + '\n')
    tabla = []
    for i in range(0, filas):
        tabla.append([])

    indice = 0
    for char in texto:
        tabla[indice].append(char)
        indice += 1
        indice = indice % filas
    
    linia = ""
    for char in tabla[0]:
        linia += char
    print(linia[0:longitudLinia])
# Out:
# Vuelta en 1
#
# I,renyl eCitinn oasns
#  ea,mairf. ttevs swe
# ea t
# Vuelta en 2
#
# Irnleiinoss  amif tv w
# at efhedhtnteB H  aesr cewh
# Vuelta en 3
#
# IelCi s  ,i.tswetufyd neB  eea  womaruC,aavm In r
# Vuelta en 4
#
# Ineios mft
# tehdttBH ercwudreiag  tnrteers  eenasn
# Vuelta en 5
#
# Iyi seit e  d e    auat ah In hkrpe e oalsatn
# taee
# Vuelta en 6
#
# Ilis itwtfdnB e wmrCav nrhe   eusmhaa Xyeoo
# iehcHt
# Vuelta en 7
#
# I n mtw h ehenhaeeven w    hnsa
# e heotn ?at"f shan
# Vuelta en 8
#
# Ieo f thtB rwdea trer ensl aeaen ii?Hhleakattf ete
# Vuelta en 9
#
# ICs,tef Be or,vIr, oehmna
# yao etH h rmCpfenao  y i
# Vuelta en 10
#
# Iisi  de  uta nhreeolantehme? t akoufa anio
# ntev
# Vuelta en 11
#
# It .
#  nhrotp swpe!mtn t iOi fikct aiokrc
# ad tnmtI
# Vuelta en 12
#
# Ii ttdBewra re eshaXeoihHteraefdtoto eIgvgdrIisy m
# Vuelta en 13
#
# Inase  nd, seh a oy m ige dpeuandceughidurcgn
# ru
# Vuelta en 14
#
# Inmwheehevnw  naehon?tfsauenebottd  dtoclrm grhra
#
# Vuelta en 15
#
# I ied  aaIhpeaa
# eleut kafSa owndvnuiinN elrbr
# oslm
# Vuelta en 16
#
# Ioftt we rres ee iHlaat tnd tnvgeIul tfr  aial"isa
# Vuelta en 17
#
# Ia ut met,e!hohliih onaetten outu.iaf yfoeabteahne
# Vuelta en 18
#
# IstfB rvr emayoeHhrCfno  ngrdei
#  efrk Ielswictmei
# Vuelta en 19
#
# InvyHaCeeootX nul Cc 'rhIoidoeNuf y Il cdfKdEa oJ
# Vuelta en 20
#
# Is d uanrelnem?taof no
# tvluilree rotlddtvlcgl edv
# Vuelta en 21
#
# I w eav  ha o t ann'oidadiccmsrbanamwaK cn H u,ne
# Vuelta en 22
#
# I
# nrt wemntiifktaor
# dtmIuneg rtaatecsEclw
# h dd,g
# Vuelta en 23
#
# I
# aec n nnt hgsa e htamssi  hloi"eaamn
# es,rdi rAt
# Vuelta en 24
#
# I tBwar saeiHeaftt IvdIs erkanloscncieJcvne ,"Ago,
# Vuelta en 25
#
# Ie  uhh l
# hOt uSntnoliuieto
# t
#  evnNu ovonyi"nntl.o
# Vuelta en 26
#
# Iae d e  ymiedeadegiucn roeenlthncvectwaot    C  f
# Vuelta en 27
#
# I,ferI haae rpn  nrdice k
# e w,tlireukdX "iyjrtr oi
# Vuelta en 28
#
# Imheen neo?faeeot dolmghatnwapcis   ere f , Totdwe
# Vuelta en 29
#
# Iaeai  sa  ieubwnoeers ln
# l,pfer
# h at a
# zgg ,t h
# Vuelta en 30
#
# Iid aheaeetkfaonvuiNerrol ttce  v pi"g
#  . o haeone
# Vuelta en 31
#
# Irh gku
# nt cdntdgt
# uebtioehlir .oeii, sdrn awd tee
# Vuelta en 32
#
# Iftw rse Hattdtveu f aa"svnis
# vo ,lfoos adwe nno e
# Vuelta en 33
#
# I.no pm i k ocdnI.e rnaecncr h e,w srn
# ahinin nma
# Vuelta en 34
#
# I tmtehhihoate uuifyoatanNve  pil h ahhaen
# yeep di
# Vuelta en 35
#
# Itean ae? uiou ilar tmeacueu aiifs ooy
# tmeeri, lta
# Vuelta en 36
#
# ItBrreaoHrfo gdi fkIlwcmi cket",oraoou
# anft aoH  a
# Vuelta en 37
#
# Ie ut  thmakehtnt  ldasneotdr g onhyu"aeosdG oSoad
# Vuelta en 38
#
# IvHCeoXnlC rIioNfyI dKE JvwXea
# ss
# h
#
# ai﻿mnP arduoi
# Vuelta en 39
#
# Is ,eay epacgdc rfect c
# coa    d aatae﻿dase  e drs
# Vuelta en 40
#
# I  arle?afn
# vule oldvclevno"f .rahemnomachtte vyih
# Vuelta en 41
#
# Isaassoakeiagrrl esflnwsnyti
#  ndinefsnshhndem uii
# Vuelta en 42
#
# Iwev aotanoddcmraawKc  ,ei y,zo wn
# etdPetnawJnP  .
# Vuelta en 43
#
# Iesm t
# "ta  rg bibidgH
# r " j g aeiyr G  tdwiho  o
# Vuelta en 44
#
# I
# r enifto
# tIngratcEl hd,n rTghw neia a eeJh ur  e
# Vuelta en 45
#
# Ie Ie
# e f nni r
# leta u i"n to adn e,oore mnouceeoe
# Vuelta en 46
#
# Iacnnths  tms ho"am e,d AtCrt,e nnp HSd v P re
# 9 o
# Vuelta en 47
#
# I e aacheyety
# rsiheodndrgl  dtotom l oudyu   e9fit
# Vuelta en 48
#
# ItwrseHat vI ralsniJve,Ao. ow ne adt aorii o o it
# Vuelta en 49
#
# I h netnei  mu
# mae    gt,ofieheee iaadishi. eeot e
# Vuelta en 50
#
# I uhlhtunnlueot vN vnint. rampencs l od co nhtxI s
# Vuelta en 51
#
# Ium,hlhntnu.ffaen elpe  aoa,
# he dd  toji pfdred IM
# Vuelta en 52
#
# Iede meedgunrentnvcwo  C rdaa ahi  irtd f i"ftheri
# Vuelta en 53
#
# Inid  esow
# mdtri  euw rwrdioym wapwdtoi e i h es h
# Vuelta en 54
#
# Ifr aern riekewtiekX"yrroaaitso- stn ee,obetotgrr,
# Vuelta en 55
#
# I tpnOki
# nu reenl  hns whv  iosuehbgu   hrslt lgyo
# Vuelta en 56
#
# Ihe e?aetdlganacs eef,TtwmatectheJch  bize e y rem
# Vuelta en 57
#
# IyCoXuC'IdN IcKaJlXl
#
# i
# t﻿,P
# rRoajuetc-t- tGhuatt
# Vuelta en 58
#
# Iei a ebner nlpe
#  ta zg, p scettoa um.f asohuebnuh
# Vuelta en 59
#
# I  tptroa eele enhhnhtftbeaeawene monsl hstkh tdcu
# Vuelta en 60
#
# Idaeetfovierltc vp"
# .oheneaott Iiu  o tt
# ytyb uki
# Vuelta en 61
#
# Is rss
# nn hfnraen taduu
# luopt,.vdiel loinT erngahe
# Vuelta en 62
#
# Ihgun dtg
# etohi oi,sr w enh-htIfrrBie-eeaeertresl.
# Vuelta en 63
#
# I vho nidcrnw  ueey oin.t,ega ns efees cyt,gomspeo
# Vuelta en 64
#
# It s atte  asnsv losaw n ci eoir  izt rr aemlke t
#
# Vuelta en 65
#
# I  am auu oetueoo
#  drt iamfeib af aeto,uo
#   u g 'a
# Vuelta en 66
#
# In mikodIeracc  , r
# hnnnas sJaur frsoeGryoosoBl  t
# Vuelta en 67
#
# IgitefooHe endb   tvsndaeetwsde lI e ecen etts dmi
# Vuelta en 68
#
# Itthiot ufotnv plhahe
# epd  tc  BirutIr uhr"imm goa
# Vuelta en 69
#
# Iennha as oem
# ,iA rie.nuHh ePsee  dhgau, hs"l p -i
# Vuelta en 70
#
# Iena?uo lrtece if o
# mei tlinhu izstsyne taiv  lreo
# Vuelta en 71
#
# II,u sd. kd eIosuty m wtaatnhefdssannaau f til  ie
# Vuelta en 72
#
# IBraHf d klcice"oao
# ntaH  r  moetoIyrmtakies :-
# e
# Vuelta en 73
#
# If r ed  o h ro s
# eem id
# setsiracte
#    anotoe ra
# Vuelta en 74
#
# I t haett dsetrgohuaod Saote . - ernmcnn
# nmpru Ban
# Vuelta en 75
#
# I h
# tSnie
#  n oin.oate,sh r c  t    nb e fh  nodrnt
# Vuelta en 76
#
# IHeXl IofIdEJwe
# sh
# imPadoddebfterG etntn eehwgnrsA
# Vuelta en 77
#
# Ihw fid gney wgsTsnhi w Jgdee.s  daooadi  ttrrebn.
# Vuelta en 78
#
# I eyeagcretcca   aa﻿ae  r  ,i terru anni't, Is rai
# Vuelta en 79
#
# I vmyu lri  tny   e
# steepahwktnumdi G hohp metwrf
# Vuelta en 80
#
# I reanvl lvlvof.aenmctevicfoza a yhtk
#  'ice  nrv
# Vuelta en 81
#
# Ie ar rck trk yto,i,ogse c,geBtaroemlobd:ga
# iae pr
# Vuelta en 82
#
# Iasokigr slwnt  dnfnhne io bes
# eaorainetccset aedi
# Vuelta en 83
#
# Iista  .n eeayntmsmoein duecttnp dtet tw tohe  hto
# Vuelta en 84
#
# Ie oaodmawc e ,ow
# tPtaJP  ie oyeeo"ieme,esehndhl e
# Vuelta en 85
#
# I elotuaoeN p
#  oegem  bh .aetn nh  amd to eodae ,a
# Vuelta en 86
#
# Is
# t r iig
#     ey  twh on"tehtrmsivsph  ehsl-
# tec
# Vuelta en 87
#
# Ia  ewesn,eht z  hs
# t asm  Bokehusueiare  tv apt,
# Vuelta en 88
#
# Ireit
# Igaclh, Th eaaeJ r hfo uytlom  rwI tnl tv d
# Vuelta en 89
#
# Ins hncdah.n otgmtdwtssnatiesY orgph:teiv.eeibifou
# Vuelta en 90
#
# I eefnirlt  " oaneor nueotttyebrkBm :ugsn d-t Idan
# Vuelta en 91
#
# In  eucun ew dftateaisdeiehcin wpiea,eoirainn ahwh
# Vuelta en 92
#
# Icnh tsh"medACtenpHdvPr
#  xhg b eel l- n rah
# vI ois
# Vuelta en 93
#
# I utdd
# bol e,d de -RIsree eaehrplaenhn'eoiet yooem
# Vuelta en 94
#
# Ieaceeyrieddg doo  uy  9iIerrnus  gr Brrvelt do ea
# Vuelta en 95
#
# Iaou oN davh
# d
# tmmr du lt ,hemec   tgd pdthtaek o
# Vuelta en 96
#
# IwsHtv asiv,o wn d oi   t rreuklt oe
# asa d edaiew.
# Vuelta en 97
#
# Ieooi ePneshto e   r  nle x uirgh
# y tl  ohsHeiev
# Vuelta en 98
#
# Ihnte m
# a  g,feeeiaih.eo si,mhi.
# taoenAi iec nsa.
# Vuelta en 99
#
# Iom onencr wran adsauef o roosBa g"rin otihil rtsi
# Vuelta en 100
#
# Iultnletv nn.rmec  dc hx wobttfninocnidasei a se
# Vuelta en 101
#
# I las  nsvo   aw   ee lrti d he  nt! hzc e ee Dokh
# Vuelta en 102
#
# Imhhtufanep aa
# ed tj frdI ue"umeo"ge aTe,gtwty-h(u
# Vuelta en 103
#
# I,tdm! hel,awfe rdhvnk imB
# asl idenav  ehwl  ch
# Vuelta en 104
#
# Id edurnnco  daai rdfifhro.ape'taIhrabufeewsot vur
# Vuelta en 105
#
# Iaa oirmcuisote,t nu eshyn mie neretd h iwn oI dts
# Vuelta en 106
#
# Ii eo
# dr ewrriy awtieihe enie nfntwnodbent-eHiafd
# Vuelta en 107
#
# I nopd ae
#  sba aiteatau icyd,nktrcolyamsrt
#   ldae
#
# Vuelta en 108
#
# Irar ikwik"roato t eoeogrbalei:h
# i dp e addfsho,hc
# Vuelta en 109
#
# Io toaensasshSt hsue-btotrios dlrptl  adste naat g
# Vuelta en 110
#
# Itnk
# urel n h isebu hstlyeuB snt sddtra atotil gc
# Vuelta en 111
#
# Iu men aedgnuedoaoet seam nomaunana  o io ,hdgn
# Vuelta en 112
#
# IeeatlaasefTwaetec bz   etpe
# ae"ina  hcwam.
# mt toa
# Vuelta en 113
#
# It r   iUer ee tiats"tngr, o   l in nu-rdp scmogns
# Vuelta en 114
#
# ICXCINIKJX
#
#
# ﻿Project Gutenberg's The Door in the
# Vuelta en 115
#
# I tatioaeitwei hvhelxhln rg ledarhe,I kns  d saarm
# Vuelta en 116
#
# Iiaenrnp
# t g  cto mfaoubuteia" ac s ,ozeesnnqdoaaa
# Vuelta en 117
#
# I,ypg e c  aadeeri,-tcr,a id,eseaoe  io,trl ed efe
# Vuelta en 118
#
# I prael nhhfbaaeemnlhthtco e  i   ionw hco
# ahiihjs
# Vuelta en 119
#
# Iehn aae e s
# ti cvfytMa "aedacehanhateidoiuiim odh
# Vuelta en 120
#
# Iaefvelcv".hnat i ot yy kf':e no t,iaoot tt csroor
# Vuelta en 121
#
# Ipt t ayhw an,wh  fltdnao egr
# st itelet ieoemenokq
# Vuelta en 122
#
# I s
# nhnantdulot.de on rghe   dtrm oar  iaanphldrfe
# Vuelta en 123
#
# Iaoeglsnni ifsnmipb-
# tohihtgs  idigwd rrttut s c
# Vuelta en 124
#
# Igndgeoio,rwehhIrBeeaetelnth"aoar nie
# ou hhahodTr-
# Vuelta en 125
#
# IhhSlt unn vemlrc.t wnerf
# oc tgsato th
# t'oRt orl
# Vuelta en 126
#
# Ivondrw eyontean fe y,ose ,aetde htnd, ltucbesd pi
# Vuelta en 127
# Iddi
#  . ewankestt..etdeol  hmasnlo  hi sdn
# miwM  h
# Vuelta en 128
#
# I  te ss oa  iei itr eletia
# ic rsduaw euiuoa o tdc
# Vuelta en 129
#
# Im
# arbiH j i  woodtttgs"s
# hv-teiw fhi  tbaecaeen
# Vuelta en 130
#
# I mauoteo r afi fat,o ug'
# Bsr age c
# tfwtnhiet yywa
# Vuelta en 131
#
# Ithem n i oktmhtmloanwn
# canfoa rlnsw.oaot o  o ile
# Vuelta en 132
#
# I ioIrc ,rhna Ju roGyool nIin t dltosdnec eekoey t
# Vuelta en 133
#
# Ien'o K e
# hPaiuby detdoeto Athocri  lan:n ata ln
# Vuelta en 134
#
# IieoH nb tsdetsel  cnet mntnf r tnpnsarlhwlucea nr
# Vuelta en 135
#
# IIe i
# tu"ta oencoethbmB :osada ya yIhg dssscotu;it
# Vuelta en 136
#
# Itituon laeed c iuI h"m ooh as,nutao(ir"hodye l s
# Vuelta en 137
#
# Ifvlitoteoluf eadaintsoilhodHaoorer  ydtTtr ta l a
# Vuelta en 138
#
# Inh som,ArenH Pe dgu slp-d ehpIoir- ont r daeufit'
# Vuelta en 139
#
# Iredn oen     i tsc siz
#  uitns ihh src,iiteeoacsaa
# Vuelta en 140
#
# In?oltc fomitih ztyeti lecrd  iiaoo te:i ar l ffce
# Vuelta en 141
#
# I cyyseng om d ei raup   rr ltdoethd, heoc ey;ile.
# Vuelta en 142
#
# I, d deouymwathfsana  i i aa de eee ac
# gnnE on n i
# Vuelta en 143
#
# Isicnecw a , rd f rduiesI oont eo aoeh btlpcddniga
# Vuelta en 144
#
# IrH  lieoona r otIrtke -
# nap ,aews(th efo pe iteie
# Vuelta en 145
#
# I  wr
# ea  potbu anemtese   a tsne
# sdawobeeh
#  dnme
# Vuelta en 146
#
# I  d   os
# e dstiat
#  aoo aahohctvr flts"rw,hsh iehe
# Vuelta en 147
#
# I timm  ,ie as.e M,tiotietire nm.iusc  er intt'.eh
# Vuelta en 148
#
# Ithetderouo at   rmn
# mr aib hoo
#  die thf ee
# h ctrd
# Vuelta en 149
#
# Ii slnhihh pzaw t s d,ous ouwue iyctswK tt, ipdice
# Vuelta en 150
#
# Ihtne  i.aes   t  bef ndnta is   lt's
# W rn un o rr
# Vuelta en 151
#
# Idnemaohshnhlnolee orvid n.lrSne
# aym'aiircllso ec
# Vuelta en 152
#
# IelIfdJes
# maodbtr tt ewnsdueczooenr:ehilwantnt d m
# Vuelta en 153
#
# I,hnfeeea,edtifeIbe'md"m aeetdye(
# m cas yuuyoi
# ,p
# Vuelta en 154
#
# Iwfdge gTniwJdes aod trendnh zo moi entpl tr.tfio
# Vuelta en 155
#
# Ik dee irdnuIai anrcnntaoggyin w g hoalsfd
# yiaaeb
# Vuelta en 156
#
# Ieegrtc  aa r itruan',I aaf wetuue"iffl wne gthcs.
# Vuelta en 157
#
# Iwoyeishbol rlreo
#  res d'est i sep l h s imiu t  t
# Vuelta en 158
#
# Ivy r ty esephknmiGhh ewfohanebonetteul
# g-m dh
# Vuelta en 159
#
# Idewdie ro pt i  nisnmtnouee- iidpact l urohd snh
# Vuelta en 160
#
# Irav vvfanceifz  hk ie r seaae  ich o wwsicalrhpe
# Vuelta en 161
#
# I saha,tt.  Peoh  solie,h,aosa f t mdl mf 'ef mngi
# Vuelta en 162
#
# I rrktkyoios ,etrelb:aiep  adphrhd sfe oisn re raa
# Vuelta en 163
#
# Itah
# rn:fltehrs eubev-n nopahTamt tmkyaes  lasty .
# Vuelta en 164
#
# Iskg ln dfhei e
# ariecstadeedmsthu oa eanirih- ik w
# Vuelta en 165
#
# Ipknrn sh shu s y B nrshta  o lgcenhonAdnntmusaspe
# Vuelta en 166
#
# Isa neanmmendetn ttt oe ttta,awtp hob sgM,tn slmfu
# Vuelta en 167
#
# I  leed aew
# gi nfs
# n .eetteet,a e
# hfyl adeuItrll g
# Vuelta en 168
#
# I adace,wttJ i ye"eeeenh iwd.nthoedrpenecieiolgesy
# Vuelta en 169
#
# Ihddeuadddfr shu.ui Bio f u,omthwbl  l ehea hiu at
# Vuelta en 170
#
# IeouoNp ee b at h m oede,tcyo
# t hne   hrhohtmosd
# Vuelta en 171
#
# IoCdIaX
# ,rae- ht'btg  deeo' u aesaa  det,rnthih,
# Vuelta en 172
#
# I trig  e tho"etmish hl
# e sf
# n aaey e
# t ahiu
#
# odrl
# Vuelta en 173
#
# Iw gsomntrh pa nitefhes,hte,rt eohsaaiu
#  chelatTod
# Vuelta en 174
#
# I eenetz stam oeuuir t p,sepnIdkaise d pmhoruadt t
# Vuelta en 175
#
# I uituiom,lg esnta tctd,io
# I s'h h l oh rtrgoaglen
# Vuelta en 176
#
# IetIal,T ae  f ylm w n vdaosmqch kel hngl-o
# tpdhcd
# Vuelta en 177
#
# Itr lehtbee n t cnehii tnehh
#  idjltv  Oirrirs"eh
# e
# Vuelta en 178
#
# Ishca. tmdtsais rp:eveiio m-.e,dwdioiwaheob snchr
# Vuelta en 179
#
# Ilh mseio i,haunceeicl -iblqfuliAto" edrompcietmot
# Vuelta en 180
#
# Iefil "ono uotybkm:gndtIa thtdsooo  i ttr l
# p i hb
# Vuelta en 181
#
# Ihgless- hfo  he nth fsT hsedmhli-o
# a tatle  a guf
# Vuelta en 182
#
# I ecne faeidihi pe,orinaw
# olr ifsp aesran
# .yet ea
# Vuelta en 183
#
# Ir
#  netulp.i i nhn etg areiinhlmfesuhch  an gc t w
# Vuelta en 184
#
# In s"eAtnHvr h  e -nrhv is o ord elftc hhigodiniah
# Vuelta en 185
#
# I andogyooo  on
# dudi r otfgea
# a n o Tee ds eme, a
# Vuelta en 186
#
# Iud
# o , e-Ireeerleh'oe oe urhkotron  aeteee  o'ent
# Vuelta en 187
#
# I!a.t  sedb r a mi"adntbt a i nHedtayhtem.o entvft
# Vuelta en 188
#
# Iaeyidgdo y ieru g rvl oeev,taoTty fetdcpkedh ibht
# Vuelta en 189
#
# Ihncwuyitgneec,meda drhodIltc s-pcutnrrglmae"ottdl
# Vuelta en 190
#
# Io Ndv
#
# mrd t,ee  g dhakohw :wWlwAhhteoSn eway
# mGc
# Vuelta en 191
#
# Iiidlolaynee gcrv we hidaaet tfu w-cs    ehkud r c
# Vuelta en 192
#
# Ist svow  i trekto
# s  diw uhoaord scir se srchahbs
# Vuelta en 193
#
# Isoebludtiaasheaeedn eehdyrhnoywrl l n wrphosctcae
# Vuelta en 194
#
# Ioienst    nexurh
#  l hHivo
# y eg Gis tcmDrer iadkt
# Vuelta en 195
#
# Iaa to tae  tu  'tspa  nt tdio swdr teSidstnIucd k
# Vuelta en 196
#
# Inema ,eeahe imi
# aeA e s. rcaar-ct eedm. wyldbhts
# Vuelta en 197
#
# Ir"a  lo h l isn n nilpioew
#    wu h lhehl Hdruwuup
# Vuelta en 198
#
# Imoec rnasuforoB "i thlrsledeioo aytrct pa" a nhoo
# Vuelta en 199
#
# IwJvhn stI,nes ttOu swrn iwa,wetenwcpmeglbluntn uo

# %%
longitudLinia = -1
for filas in range(1, 200):
    print("Vuelta en " + str(filas) + '\n')
    tabla = []
    for i in range(0, filas):
        tabla.append([])

    indice = 0
    for char in texto:
        tabla[indice].append(char)
        indice += 1
        indice = indice % filas
    
    linia = ""
    for char in tabla[0]:
        linia += char
    print(linia[0:-1])
