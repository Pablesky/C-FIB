# %%
import os
actual = os.getcwd()
actual
# Out:
# '/home/pablesky/Documentos/C-FIB/Sesion1'

# %%
RTEXTO = actual + '/cesar'
RTEXTOS = actual + '/Textos/*.txt'

# %%
from glob import glob
LTEXTOS = glob(RTEXTOS)
LTEXTOS;

# %%
FTEXTO = open('cesarExamen.txt')
TEXTO = FTEXTO.read()
TEXTO
# Out:
# '\n\ufeff⍩⍑⍨⍣⍞⍜⍓ ⍠⍔⍓⍞⍧⍛⍞⍑⍠\'⍒ ⍓⍡⍞ ⍝⍨⍨⍑ ⍢⍧ ⍓⍡⍞ ⍖⍚⍥⍥ ⍚⍧⍝ ⍨⍓⍡⍞⍑ ⍒⍓⍨⍑⍢⍞⍒, ⍛⍘ ⍡. ⍠. ⍖⍞⍥⍥⍒\n\n⍓⍡⍢⍒ ⍞⍛⍨⍨⍤ ⍢⍒ ⍟⍨⍑ ⍓⍡⍞ ⍔⍒⍞ ⍨⍟ ⍚⍧⍘⍨⍧⍞ ⍚⍧⍘⍖⍡⍞⍑⍞ ⍚⍓ ⍧⍨ ⍜⍨⍒⍓ ⍚⍧⍝ ⍖⍢⍓⍡\n⍚⍥⍦⍨⍒⍓ ⍧⍨ ⍑⍞⍒⍓⍑⍢⍜⍓⍢⍨⍧⍒ ⍖⍡⍚⍓⍒⍨⍞⍕⍞⍑.  ⍘⍨⍔ ⍦⍚⍘ ⍜⍨⍩⍘ ⍢⍓, ⍠⍢⍕⍞ ⍢⍓ ⍚⍖⍚⍘ ⍨⍑\n⍑⍞-⍔⍒⍞ ⍢⍓ ⍔⍧⍝⍞⍑ ⍓⍡⍞ ⍓⍞⍑⍦⍒ ⍨⍟ ⍓⍡⍞ ⍩⍑⍨⍣⍞⍜⍓ ⍠⍔⍓⍞⍧⍛⍞⍑⍠ ⍥⍢⍜⍞⍧⍒⍞ ⍢⍧⍜⍥⍔⍝⍞⍝\n⍖⍢⍓⍡ ⍓⍡⍢⍒ ⍞⍛⍨⍨⍤ ⍨⍑ ⍨⍧⍥⍢⍧⍞ ⍚⍓ ⍠⍔⍓⍞⍧⍛⍞⍑⍠.⍧⍞⍓\n\n\n⍓⍢⍓⍥⍞: ⍓⍡⍞ ⍝⍨⍨⍑ ⍢⍧ ⍓⍡⍞ ⍖⍚⍥⍥ ⍚⍧⍝ ⍨⍓⍡⍞⍑ ⍒⍓⍨⍑⍢⍞⍒\n\n⍚⍔⍓⍡⍨⍑: ⍡. ⍠. ⍖⍞⍥⍥⍒\n\n⍑⍞⍥⍞⍚⍒⍞ ⍝⍚⍓⍞: ⍣⍔⍥⍘ 22, 2005 [⍞⍛⍨⍨⍤ #456]\n[⍓⍡⍢⍒ ⍟⍢⍥⍞ ⍖⍚⍒ ⍟⍢⍑⍒⍓ ⍩⍨⍒⍓⍞⍝ ⍢⍧ ⍦⍚⍑⍜⍡, 1996]\n\n⍥⍚⍧⍠⍔⍚⍠⍞: ⍞⍧⍠⍥⍢⍒⍡\n\n\n*** ⍒⍓⍚⍑⍓ ⍨⍟ ⍓⍡⍢⍒ ⍩⍑⍨⍣⍞⍜⍓ ⍠⍔⍓⍞⍧⍛⍞⍑⍠ ⍞⍛⍨⍨⍤ ⍝⍨⍨⍑ ⍢⍧ ⍓⍡⍞ ⍖⍚⍥⍥ ⍚⍧⍝ ⍨⍓⍡⍞⍑ ⍒⍓⍨⍑⍢⍞⍒ ***\n\n\n\n\n⍓⍡⍢⍒ ⍞⍓⍞⍗⍓ ⍖⍚⍒ ⍜⍑⍞⍚⍓⍞⍝ ⍛⍘ ⍣⍔⍝⍢⍓⍡ ⍛⍨⍒⍒, ⍨⍦⍚⍡⍚, ⍧⍞⍛⍑⍚⍒⍤⍚.\n⍓⍡⍞ ⍞⍐⍔⍢⍩⍦⍞⍧⍓: ⍚⍧ ⍢⍛⍦-⍜⍨⍦⍩⍚⍓⍢⍛⍥⍞ 486/50, ⍚ ⍡⍞⍖⍥⍞⍓⍓-⍩⍚⍜⍤⍚⍑⍝\n⍒⍜⍚⍧⍣⍞⍓ ⍢⍢⍜ ⍟⍥⍚⍓⍛⍞⍝ ⍒⍜⍚⍧⍧⍞⍑, ⍚⍧⍝ ⍜⍚⍥⍞⍑⍚ ⍑⍞⍜⍨⍠⍧⍢⍓⍢⍨⍧ ⍒⍘⍒⍓⍞⍦⍒\'\n⍦/600 ⍒⍞⍑⍢⍞⍒ ⍩⍑⍨⍟⍞⍒⍒⍢⍨⍧⍚⍥ ⍨⍜⍑ ⍒⍨⍟⍓⍖⍚⍑⍞ ⍚⍧⍝ ⍑⍢⍒⍜ ⍚⍜⍜⍞⍥⍞⍑⍚⍓⍨⍑ ⍛⍨⍚⍑⍝\n⍝⍨⍧⍚⍓⍞⍝ ⍛⍘ ⍜⍚⍥⍞⍑⍚ ⍑⍞⍜⍨⍠⍧⍢⍓⍢⍨⍧ ⍒⍘⍒⍓⍞⍦⍒.\n\n\n\n\n\n\n\n\n⍓⍡⍞ ⍝⍨⍨⍑\n⍢⍧ ⍓⍡⍞ ⍖⍚⍥⍥\n⍚⍧⍝ ⍨⍓⍡⍞⍑ ⍒⍓⍨⍑⍢⍞⍒\n\n⍛⍘\n⍡. ⍠. ⍖⍞⍥⍥⍒\n\n\n\n\n\n\n⍜⍨⍧⍓⍞⍧⍓
# ...

# %%
textoNum = []
for char in TEXTO:
    if not char in ['\n', '\ufeff']:
        print(char, end='')
        print(' ' + str(ord(char)))
        textoNum.append(ord(char))
# Out:
# ⍩ 9065
# ⍑ 9041
# ⍨ 9064
# ⍣ 9059
# ⍞ 9054
# ⍜ 9052
# ⍓ 9043
#   32
# ⍠ 9056
# ⍔ 9044
# ⍓ 9043
# ⍞ 9054
# ⍧ 9063
# ⍛ 9051
# ⍞ 9054
# ⍑ 9041
# ⍠ 9056
# ' 39
# ⍒ 9042
#   32
# ⍓ 9043
# ⍡ 9057
# ⍞ 9054
#   32
# ⍝ 9053
# ⍨ 9064
# ⍨ 9064
# ⍑ 9041
#   32
# ⍢ 9058
# ⍧ 9063
#   32
# ⍓ 9043
# ⍡ 9057
# ⍞ 9054
#   32
# ⍖ 9046
# ⍚ 9050
# ⍥ 9061
# ⍥ 9061
#   32
# ⍚ 9050
# ⍧ 9063
# ⍝ 9053
#   32
# ⍨ 9064
# ⍓ 9043
# ⍡ 9057
# ⍞ 9054
# ⍑ 9041
#   32
# ⍒ 9042
# ⍓ 9043
# ⍨ 9064
# ⍑ 9041
# ⍢ 9058
# ⍞ 9054
# ⍒ 9042
# , 44
#   32
# ⍛ 9051
# ⍘ 9048
#   32
# ⍡ 9057
# . 46
#   32
# ⍠ 9056
# . 46
#   32
# ⍖ 9046
# ⍞ 9054
# ⍥ 9061
# ⍥ 9061
# ⍒ 9042
# ⍓ 9043
# ⍡ 9057
# ⍢ 9058
# ⍒ 9042
#   32
# ⍞ 9054
# ⍛ 9051
# ⍨ 9064
# ⍨ 9064
# ⍤ 9060
#   32
# ⍢ 9058
# ⍒ 9042
#   32
# ⍟ 9055
# ⍨ 9064
# ⍑ 9041
#   32
# ⍓ 9043
# ⍡ 9057
# ⍞ 9054
#   32
# ⍔ 9044
# ⍒ 9042
# ⍞ 9054
#   32
# ⍨ 9064
# ⍟ 9055
#   32
# ⍚ 9050
# ⍧ 9063
# ⍘ 9048
# ⍨ 9064
# ⍧ 9063
# ⍞ 9054
#   32
# ⍚ 9050
# ⍧ 9063
# ⍘ 9048
# ⍖ 9046
# ⍡ 9057
# ⍞ 9054
# ...

# %%
listaAjustada = []
for elem in textoNum:
    if elem > 9000:
        listaAjustada.append(elem)

for elem in listaAjustada:
    print(chr(elem), end=' ')
    print(elem)
# Out:
# ⍩ 9065
# ⍑ 9041
# ⍨ 9064
# ⍣ 9059
# ⍞ 9054
# ⍜ 9052
# ⍓ 9043
# ⍠ 9056
# ⍔ 9044
# ⍓ 9043
# ⍞ 9054
# ⍧ 9063
# ⍛ 9051
# ⍞ 9054
# ⍑ 9041
# ⍠ 9056
# ⍒ 9042
# ⍓ 9043
# ⍡ 9057
# ⍞ 9054
# ⍝ 9053
# ⍨ 9064
# ⍨ 9064
# ⍑ 9041
# ⍢ 9058
# ⍧ 9063
# ⍓ 9043
# ⍡ 9057
# ⍞ 9054
# ⍖ 9046
# ⍚ 9050
# ⍥ 9061
# ⍥ 9061
# ⍚ 9050
# ⍧ 9063
# ⍝ 9053
# ⍨ 9064
# ⍓ 9043
# ⍡ 9057
# ⍞ 9054
# ⍑ 9041
# ⍒ 9042
# ⍓ 9043
# ⍨ 9064
# ⍑ 9041
# ⍢ 9058
# ⍞ 9054
# ⍒ 9042
# ⍛ 9051
# ⍘ 9048
# ⍡ 9057
# ⍠ 9056
# ⍖ 9046
# ⍞ 9054
# ⍥ 9061
# ⍥ 9061
# ⍒ 9042
# ⍓ 9043
# ⍡ 9057
# ⍢ 9058
# ⍒ 9042
# ⍞ 9054
# ⍛ 9051
# ⍨ 9064
# ⍨ 9064
# ⍤ 9060
# ⍢ 9058
# ⍒ 9042
# ⍟ 9055
# ⍨ 9064
# ⍑ 9041
# ⍓ 9043
# ⍡ 9057
# ⍞ 9054
# ⍔ 9044
# ⍒ 9042
# ⍞ 9054
# ⍨ 9064
# ⍟ 9055
# ⍚ 9050
# ⍧ 9063
# ⍘ 9048
# ⍨ 9064
# ⍧ 9063
# ⍞ 9054
# ⍚ 9050
# ⍧ 9063
# ⍘ 9048
# ⍖ 9046
# ⍡ 9057
# ⍞ 9054
# ⍑ 9041
# ⍞ 9054
# ⍚ 9050
# ⍓ 9043
# ⍧ 9063
# ⍨ 9064
# ⍜ 9052
# ⍨ 9064
# ⍒ 9042
# ⍓ 9043
# ⍚ 9050
# ⍧ 9063
# ⍝ 9053
# ⍖ 9046
# ⍢ 9058
# ⍓ 9043
# ⍡ 9057
# ⍚ 9050
# ⍥ 9061
# ⍦ 9062
# ...

# %%
listaNew = [elem - 9000 for elem in listaAjustada]
listaNew
# Out:
# [65,
#  41,
#  64,
#  59,
#  54,
#  52,
#  43,
#  56,
#  44,
#  43,
#  54,
#  63,
#  51,
#  54,
#  41,
#  56,
#  42,
#  43,
#  57,
#  54,
#  53,
#  64,
#  64,
#  41,
#  58,
#  63,
#  43,
#  57,
#  54,
#  46,
#  50,
#  61,
#  61,
#  50,
#  63,
#  53,
#  64,
#  43,
#  57,
#  54,
#  41,
#  42,
#  43,
#  64,
#  41,
#  58,
#  54,
#  42,
#  51,
#  48,
#  57,
#  56,
#  46,
#  54,
#  61,
#  61,
#  42,
#  43,
#  57,
#  58,
#  42,
#  54,
#  51,
#  64,
#  64,
#  60,
#  58,
#  42,
#  55,
#  64,
#  41,
#  43,
#  57,
#  54,
#  44,
#  42,
#  54,
#  64,
#  55,
#  50,
#  63,
#  48,
#  64,
#  63,
#  54,
#  50,
#  63,
#  48,
#  46,
#  57,
#  54,
#  41,
#  54,
#  50,
#  43,
#  63,
#  64,
#  52,
#  64,
#  42,
#  43,
#  50,
#  63,
#  53,
#  46,
#  58,
#  43,
#  57,
#  50,
#  61,
#  62,
#  64,
#  42,
#  43,
#  63,
#  64,
#  41,
#  54,
#  42,
#  43,
#  41,
#  58,
#  52,
#  43,
#  58,
#  64,
#  63,
#  42,
#  46,
#  57,
#  50,
#  43,
#  42,
#  64,
#  54,
#  45,
#  54,
#  41,
#  48,
#  64,
#  44,
#  62,
# ...

# %%
paddle = 24
textoNum = []
for char in TEXTO:
    if ord(char) > 9000:
        print(chr(((ord(char) - 9000 - paddle) % 26) + ord('A')), end='')
    else:
        print(char, end='')
# Out:
# RPROJECT GUTENBERG'S THE DOOR IN THE WALL AND OTHER STORIES, BY H. G. WELLS
#
# THIS EBOOK IS FOR THE USE OF ANYONE ANYWHERE AT NO COST AND WITH
# ALMOST NO RESTRICTIONS WHATSOEVER.  YOU MAY COPY IT, GIVE IT AWAY OR
# RE-USE IT UNDER THE TERMS OF THE PROJECT GUTENBERG LICENSE INCLUDED
# WITH THIS EBOOK OR ONLINE AT GUTENBERG.NET
#
#
# TITLE: THE DOOR IN THE WALL AND OTHER STORIES
#
# AUTHOR: H. G. WELLS
#
# RELEASE DATE: JULY 22, 2005 [EBOOK #456]
# [THIS FILE WAS FIRST POSTED IN MARCH, 1996]
#
# LANGUAGE: ENGLISH
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK DOOR IN THE WALL AND OTHER STORIES ***
#
#
#
#
# THIS ETEXT WAS CREATED BY JUDITH BOSS, OMAHA, NEBRASKA.
# THE EQUIPMENT: AN IBM-COMPATIBLE 486/50, A HEWLETT-PACKARD
# SCANJET IIC FLATBED SCANNER, AND CALERA RECOGNITION SYSTEMS'
# M/600 SERIES PROFESSIONAL OCR SOFTWARE AND RISC ACCELERATOR BOARD
# DONATED BY CALERA RECOGNITION SYSTEMS.
#
#
#
#
#
#
#
#
# THE DOOR
# IN THE WALL
# AND OTHER STORIES
#
# BY
# H. G. WELLS
#
#
#
#
#
# ...
