# %%
#20
import os
current = os.getcwd()
current
# Out:
# '/home/pablesky/Documentos/C-FIB/Sesion1'

# %%
TEXTO = open(current + '/escitala').read()
TEXTO
encriptado = ""
for char in TEXTO:
    if not char in ['\n', '\ufeff']:
        encriptado += char
        
TEXTO
# Out:
# "ETeyiecgG\n FEo9E  \nN\n m e,snnHegae h\neeffihnllo ryroeaalalree\noebctsscereIr atcoor\n eurpin eone yebrp d nbtnecetmrlil;d rsdeahneuaehdaeo  nylmp o,eerhherratralros  m t doi nopg heaa oer lse  ot Bhnoo-e..R2-Sn1AB \nE\nsaia\n  denor m i   .stteirBe,nfnynlyrubedu arhtsr pn\neisirbnoeintelfswnu ,f,renra aoee\nais utetw  het  nia rnxeisrowpa tepil ssseias nhhtl utinihas rki rr findyofres onntuo oetnnuno e08E\n5RO  W\ntndrist  d .faatmat   i,f un e\nd.d. etoninlne e emhtbssioeigmato maeieoso\no e ee itt,dhke gs  hattaahchaslpedeygs kao\nbenondbtsu mvtadia  ms toniieheenteiarmh sf  sonntorlr o ,esssrWl1\nA\n) Y   To eltthabea ak .a hInsa etttosho\n  Nata etedtBaotayeet ontlr s uoai vru usrtdtdpcn    i,taetop yohslaael iaa r eua ssaudts ,uiaaese n npfia b tgsnci  eh snosar  aos\neaswedy kP   eegee8\nR\n\nA   HHrway oetenbInin kpetohla h  rsiu\nyIudiradrva edbidreg tnsiiapyigfrnaeegiroth,o oa hthtm ynt fois e  vlsytspuacasr i snt  ea torsaenidhgsinnces \n  rmhaxatedmemeamdfeevl  m ,  r
# ...

# %%
from glob import glob
RCLEAN = current + '/Textos/*.txt'
libros = glob(RCLEAN)
libros;

# %%
encriptado = TEXTO
for filas in range(194, 195):
    print("Vuelta en " + str(filas) + '\n')
    tabla = []
    for i in range(0, filas):
        tabla.append([])

    indice = 0
    for char in encriptado:
        tabla[indice].append(char)
        indice += 1
        indice = indice % filas
    """
    for fila in tabla:
        for elem in fila:
            print(elem, end='')
        print('\n', end='')
    """
    
    linia = ""
    for fila in tabla:
        linia = ""
        for char in fila:
            linia += char
        print(linia + '\n')
# Out:
# Vuelta en 194
#
# EBook of The Research Magnificent, by H. G. Wells
#
# ﻿
#
# The Project Gutenberg EBook of The Research Magnific
#
# ent, by H. G. Wells
#
# This eBook is for the use of an
#
# yone anywhere at no cost and with
# almost no restrict
#
# ions whatsoever.  You may copy it, give it away or
# r
#
# e-use it under the terms of the Project Gutenberg Li
#
# cense included
# with this eBook or online at gutenber
#
# g.org
#
#
# Title: The Research Magnificent
#
# Author: H.
#
# G. Wells
#
# Posting Date: August 3, 2008 [EBook #1138]
#
#
# Release Date: December, 1997
# Last Updated: March 2,
#
#  2018
#
# Language: English
#
# Character set encoding: UT
#
# F-8
#
# *** START OF THIS PROJECT GUTENBERG EBOOK THE R
#
# ESEARCH MAGNIFICENT ***
#
#
#
#
# Produced by Donald Lains
#
# on
#
#
#
#
#
# THE RESEARCH MAGNIFICENT
#
# by H. G. Wells
#
# (1
#
# 915)
#
#
#
# CONTENTS
#
#
#      THE PRELUDE
#
#            ON F
#
# EAR AND ARISTOCRACY
#
#
#      THE STORY
#
#        I.  THE
# ...

# %%
TEXTO = open('EscitalaExamen')
TEXTO = TEXTO.read()

# %%
encriptado = TEXTO
for filas in range(1, 200):
    print("Vuelta en " + str(filas) + '\n')
    tabla = []
    for i in range(0, filas):
        tabla.append([])

    indice = 0
    for char in encriptado:
        tabla[indice].append(char)
        indice += 1
        indice = indice % filas
    """
    for fila in tabla:
        for elem in fila:
            print(elem, end='')
        print('\n', end='')
    """
    
    linia = ""
    for fila in tabla:
        linia = ""
        for char in fila:
            linia += char
        break
    
    print(linia[0:50] + '\n')
# Out:
# Vuelta en 1
#
# RTT rree hh us .gde ernnsAutTfoA2c wewns Cssyeiife
#
# Vuelta en 2
#
# RTre hu geensuTo2 en syif0=er   rucniineto
# osNaey
#
#
# Vuelta en 3
#
# R ehu.erstocessefeer au1i,ee
# nNeys rint,,mohefsn l
#
# Vuelta en 4
#
# Rr ugesT2e yf=r rcint
# say oii ,vHeet iB eihdrraun1
#
# Vuelta en 5
#
# Rrh.eAow e0y un,tnNo roa,  fto Hegpurs tMrfhe
# neai
#
# Vuelta en 6
#
# Reuesoesfe uie
# Ny it,oes   ahnr ne fyfTUa2shbotEoe
#
# Vuelta en 7
#
# Re rTwseran}
# r
# ri o tlathu,w1 fesltis
#  hiseestea
#
# Vuelta en 8
#
# R gs2 frritsyoi,He BehranMrysea eblioG
# ehe lB ri a
#
# Vuelta en 9
#
# RheteeeaieNsi,of sa
# rweey
# U7seoUoi=t t h n hTn aa
#
# Vuelta en 10
#
# Rheo 0 ntN o, t epr MfenapsoiMyihwia 2 reh tn6iwnl
#
# Vuelta en 11
#
# R ncyyu}sso eragroenelirba}isdwhBa1oTc  nbsniet or
#
# Vuelta en 12
#
# Rusef i
# yi,e  hrn yTasbtoye  s o Tn atnannemofsl t
#
# Vuelta en 13
#
# Rsus=uero, r  ,tr U sh} edmh,rro   nae.liS t noo e
#
# Vuelta en 14
#
# R Tsrn
#
# ...
